# %%
# !pip install modelscope

# %%
# !pip install -q modelscope addict

# %%
# !pip install torch --extra-index-url https://download.pytorch.org/whl/cpu
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cpu
# ...

# %%
# !pip uninstall -y datasets
# Out:
# Found existing installation: datasets 2.18.0
# Uninstalling datasets-2.18.0:
#   Successfully uninstalled datasets-2.18.0

# %%
# !pip install "datasets==2.18.0"
# Out:
# ...
#   Using cached datasets-2.18.0-py3-none-any.whl.metadata (20 kB)
# ...
# Using cached datasets-2.18.0-py3-none-any.whl (510 kB)
# ...

# %%
# !pip install "modelscope>=1.15.0,<2.0.0"

# %%
from modelscope.pipelines import pipeline

pipe = pipeline(
    'text-to-image-synthesis',
    model='iic/ofa_text-to-image-synthesis_coco_large_en'
)

prompt = "a cute cat sitting on a sofa"
result = pipe({'text': prompt})
image_path = result['output_img']

from PIL import Image
import matplotlib.pyplot as plt

plt.imshow(Image.open(image_path))
plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-416219795.py in <cell line: 0>()
# ----> 1 from modelscope.pipelines import pipeline
#       2
#       3 pipe = pipeline(
#       4     'text-to-image-synthesis',
#       5     model='iic/ofa_text-to-image-synthesis_coco_large_en'
#
# /usr/local/lib/python3.12/dist-packages/modelscope/pipelines/__init__.py in <module>
#       2
#       3 from . import audio, cv, multi_modal, nlp
# ----> 4 from .base import Pipeline
#       5 from .builder import pipeline
#
# /usr/local/lib/python3.12/dist-packages/modelscope/pipelines/base.py in <module>
#      14
#      15 from modelscope.models.base import Model
# ---> 16 from modelscope.msdatasets import MsDataset
#      17 from modelscope.outputs import TASK_OUTPUTS, ModelOutputBase
#      18 from modelscope.pipeline_inputs import TASK_INPUTS, check_input_type
#
# ...
